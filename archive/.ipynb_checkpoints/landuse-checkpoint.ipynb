# %% [markdown]
# ### By downloading data
# https://hub.scag.ca.gov/datasets/3e9c888c6aae45ab8e140abeec42cd1e_0/about

# %%
import zipfile

with zipfile.ZipFile("Data/landuse.gpkg.zip", 'r') as zip_ref:
    zip_ref.extractall("Data/")

luGdf = gpd.read_file("Data/landuse.gpkg")
# Out:
# /opt/anaconda3/envs/uds/lib/python3.12/site-packages/pyogrio/raw.py:198: RuntimeWarning: This version of GeoPackage user_version=0x000028A0 (10400, v1.4.0) on 'Data/landuse.gpkg' may only be partially supported
#   return ogr_read(
# /opt/anaconda3/envs/uds/lib/python3.12/site-packages/pyogrio/raw.py:198: RuntimeWarning: Non-conformant content for record 1 in column YEAR_GP, 2015-05-01T00:00:00.0Z, successfully parsed
#   return ogr_read(

# %%
selected_cols = ['ACRES', 'GEOID20', 'DEN_AVG', 'ZN19_SCAG', 'LU19', 'geometry']
luGdf = luGdf[selected_cols]

# %%
luGdf
# Out:
#             ACRES          GEOID20  DEN_AVG ZN19_SCAG    LU19  \
# 0        0.222311  060371132321019      4.5      1111  1110.0
# 1        0.227461  060371132321019      4.5      1111  1110.0
# 2        0.221317  060371132321019      4.5      1111  1110.0
# 3        0.271077  060371132321019      3.5      1111  1110.0
# 4        0.341507  060371132321019      3.5      1111  1110.0
# ...           ...              ...      ...       ...     ...
# 2406368  2.048322  060374033271017      0.0      1300  3100.0
# 2406369  0.126775  060371835101004      6.5      1111  1110.0
# 2406370  0.068799  060375750012013      0.0      1110     NaN
# 2406371  0.609390  060379200131007      0.0      1111  3100.0
# 2406372  0.142198  060379200131007      0.0      1111  3100.0
#
#                                                   geometry  LU19_major_code  \
# 0        MULTIPOLYGON (((350737.273 3787751.664, 350737...           1100.0
# 1        MULTIPOLYGON (((350736.997 3787731.395, 350737...           1100.0
# 2        MULTIPOLYGON (((350731.662 3787710.984, 350732...           1100.0
# 3        MULTIPOLYGON (((350521.208 3787753.444, 350522...           1100.0
# 4        MULTIPOLYGON (((350521.208 3787753.444, 350506...           1100.0
# ...                                                    ...              ...
# 2406368  MULTIPOLYGON (((423748.455 3764513.293, 423682...           3100.0
# 2406369  MULTIPOLYGON (((388846.009 3775726.33, 388845....           1100.0
# 2406370  MULTIPOLYGON (((393376.57 3739866.886, 393382....              NaN
# 2406371  MULTIPOLYGON (((360595.271 3809233.113, 360595...           3100.0
# 2406372  MULTIPOLYGON (((360536.34 3809407.251, 360536....           3100.0
#
#         LU19_major_label      area_m2
# 0            Residential   899.661199
# 1            Residential   920.500014
# 2            Residential   895.639876
# 3            Residential  1097.008942
# 4            Residential  1382.030011
# ...                  ...          ...
# 2406368              NaN  8289.271337
# 2406369      Residential   513.038838
# 2406370              NaN   278.420568
# 2406371              NaN  2466.117382
# 2406372              NaN   575.455460
#
# [2406373 rows x 9 columns]

# %%
luGdf['LU19'] = pd.to_numeric(luGdf['LU19'], errors='coerce')

lu19_major_categories = {
    1100: "Residential",
    1200: "Commercial and Services",
    1300: "Industrial",
    1400: "Transportation, Communications, and Utilities",
    1500: "Public Facilities",
    1600: "Open Space and Recreation",
    1700: "Vacant",
    1800: "Water",
    1900: "Agriculture",
    8888: "Undevelopable or Protected Land",
    9999: "LandUnknown"
}

luGdf['LU19_major_code'] = (luGdf['LU19'] // 100) * 100
luGdf.loc[luGdf['LU19'] == 8888, 'LU19_major_code'] = 8888
luGdf.loc[luGdf['LU19'] == 9999, 'LU19_major_code'] = 9999

luGdf['LU19_major_label'] = luGdf['LU19_major_code'].map(lu19_major_categories)

# %%
import matplotlib.pyplot as plt

luGdf.plot(column="LU19_major_label", 
           cmap="Set3",              
           legend=True, 
           figsize=(12, 12))

plt.title("Land Use Categories (SCAG LU19 Major Labels)")
plt.axis("off")
plt.show()

# %% [markdown]
# #### Calculating the proportion of landuse type for each tract

# %%
# making column of GEOID by using the first 11 digit out of 15 digit(block level)
luGdf['GEOID'] = luGdf['GEOID20'].str[:11]

# %%
# converting the gdf into meter based projection
luGdf_proj = luGdf.to_crs(epsg=3497)

# making a column that shows the area of each parcel
luGdf_proj['area_m2'] = luGdf_proj.geometry.area

# %%
# calculating the area of each landuse type for each tract
# tract_lu has rows that shows the area of each landuse type for each tract (one tract has a couple of rows for each landuse type)
tract_lu = luGdf_proj.groupby(['GEOID', 'LU19_major_label'])['area_m2'].sum().reset_index()

# %%
# calculating the total area for each tract and name it tract_total
tract_total = tract_lu.groupby('GEOID')['area_m2'].sum().reset_index(name='total_area_m2')

# %%
# calculating the proportion of each land use type for each census tract
tract_lu = tract_lu.merge(tract_total, on='GEOID')
tract_lu['percent'] = tract_lu['area_m2'] / tract_lu['total_area_m2'] * 100

# %%
# extracting the rows with "Residential"
tract_residential = tract_lu[tract_lu['LU19_major_label'] == 'Residential'][['GEOID', 'percent']]
tract_residential = tract_residential.rename(columns={'percent': 'pct_residential'})

# %%
for year in range(2019, 2025):
    path = f"Data/tl_shp_library/tl_{year}_06_tract.zip"
    tracts = gpd.read_file(path)
    la_tracts = tracts[(tracts["COUNTYFP"] == "037") & (tracts["STATEFP"] == "06")]
    
    var_name = f"tracts{str(year)[-2:]}"
    globals()[var_name] = la_tracts

# %%
tract_residential = tract_residential.set_index("GEOID")
tracts23 = tracts23.set_index("GEOID")

merged = tracts23.join(tract_residential, how="left")

# %%
#Mapping
merged.plot(column='pct_residential', cmap='YlGnBu', legend=True, figsize=(12, 10))
# Out:
# <Axes: >

# %% [markdown]
# ### By API

# %%
import requests
import geopandas as gpd
from shapely.geometry import Polygon

# ベースURLとパラメータ
url = "https://services5.arcgis.com/vYSHcRQuTn4O8o35/arcgis/rest/services/" \
      "2019_Regional_Land_Use_Information_for_Los_Angeles_County/FeatureServer/0/query"

base_params = {
    "where": "1=1",
    "outFields": "ACRES,ZN19_SCAG,LU19,Shape__Area,Shape__Length,DEN_AVG,GEOID20",
    "outSR": 4326,
    "f": "json",
    "returnGeometry": "true",
    "resultRecordCount": 2000  # 最大件数
}

# 全件収集用ループ
records = []
offset = 0
while True:
    params = base_params.copy()
    params["resultOffset"] = offset

    response = requests.get(url, params=params)
    data = response.json()

    features = data.get("features", [])
    if not features:
        break

    for feature in features:
        attrs = feature.get("attributes", {})
        geom_raw = feature.get("geometry")

        # ArcGIS geometry → shapely Polygon
        if isinstance(geom_raw, dict) and "rings" in geom_raw and geom_raw["rings"]:
            try:
                geom = Polygon(geom_raw["rings"][0])  # 外周のみ使用
                attrs["geometry"] = geom
                records.append(attrs)
            except Exception as e:
                continue

    offset += len(features)
    print(f"Downloaded {offset} features...")

    # Safety break (optional)
    if data.get("exceededTransferLimit") is not True:
        break

# GeoDataFrame 作成
ludf = gpd.GeoDataFrame(records, geometry="geometry", crs="EPSG:4326")
# Out:
# Downloaded 2000 features...
# Downloaded 4000 features...
# Downloaded 6000 features...
# Downloaded 8000 features...
# Downloaded 10000 features...
# Downloaded 12000 features...
# Downloaded 14000 features...
# Downloaded 16000 features...
# Downloaded 18000 features...
# Downloaded 20000 features...
# Downloaded 22000 features...
# Downloaded 24000 features...
# Downloaded 26000 features...
# Downloaded 28000 features...
# Downloaded 30000 features...
# Downloaded 32000 features...
# Downloaded 34000 features...
# Downloaded 36000 features...
# Downloaded 38000 features...
# Downloaded 40000 features...
# Downloaded 42000 features...
# Downloaded 44000 features...
# Downloaded 46000 features...
# Downloaded 48000 features...
# Downloaded 50000 features...
# Downloaded 52000 features...
# Downloaded 54000 features...
# Downloaded 56000 features...
# Downloaded 58000 features...
# Downloaded 60000 features...
# Downloaded 62000 features...
# Downloaded 64000 features...
# Downloaded 66000 features...
# Downloaded 68000 features...
# Downloaded 70000 features...
# Downloaded 72000 features...
# Downloaded 74000 features...
# Downloaded 76000 features...
# Downloaded 78000 features...
# Downloaded 80000 features...
# Downloaded 82000 features...
# Downloaded 84000 features...
# Downloaded 86000 features...
# Downloaded 88000 features...
# Downloaded 90000 features...
# Downloaded 92000 features...
# Downloaded 94000 features...
# Downloaded 96000 features...
# Downloaded 98000 features...
# Downloaded 100000 features...
# Downloaded 102000 features...
# Downloaded 104000 features...
# Downloaded 106000 features...
# Downloaded 108000 features...
# Downloaded 110000 features...
# Downloaded 112000 features...
# Downloaded 114000 features...
# Downloaded 116000 features...
# Downloaded 118000 features...
# Downloaded 120000 features...
# Downloaded 122000 features...
# Downloaded 124000 features...
# Downloaded 126000 features...
# Downloaded 128000 features...
# Downloaded 130000 features...
# Downloaded 132000 features...
# Downloaded 134000 features...
# Downloaded 136000 features...
# Downloaded 138000 features...
# Downloaded 140000 features...
# Downloaded 142000 features...
# Downloaded 144000 features...
# Downloaded 146000 features...
# Downloaded 148000 features...
# Downloaded 150000 features...
# Downloaded 152000 features...
# Downloaded 154000 features...
# Downloaded 156000 features...
# Downloaded 158000 features...
# Downloaded 160000 features...
# Downloaded 162000 features...
# Downloaded 164000 features...
# Downloaded 166000 features...
# Downloaded 168000 features...
# Downloaded 170000 features...
# Downloaded 172000 features...
# Downloaded 174000 features...
# Downloaded 176000 features...
# Downloaded 178000 features...
# Downloaded 180000 features...
# Downloaded 182000 features...
# Downloaded 184000 features...
# Downloaded 186000 features...
# Downloaded 188000 features...
# Downloaded 190000 features...
# Downloaded 192000 features...
# Downloaded 194000 features...
# Downloaded 196000 features...
# Downloaded 198000 features...
# Downloaded 200000 features...
# Downloaded 202000 features...
# Downloaded 204000 features...
# Downloaded 206000 features...
# Downloaded 208000 features...
# Downloaded 210000 features...
# Downloaded 212000 features...
# Downloaded 214000 features...
# Downloaded 216000 features...
# Downloaded 218000 features...
# Downloaded 220000 features...
# Downloaded 222000 features...
# Downloaded 224000 features...
# Downloaded 226000 features...
# Downloaded 228000 features...
# Downloaded 230000 features...
# Downloaded 232000 features...
# Downloaded 234000 features...
# Downloaded 236000 features...
# Downloaded 238000 features...
# Downloaded 240000 features...
# Downloaded 242000 features...
# Downloaded 244000 features...
# Downloaded 246000 features...
# Downloaded 248000 features...
# Downloaded 250000 features...
# Downloaded 252000 features...
# Downloaded 254000 features...
# Downloaded 256000 features...
# Downloaded 258000 features...
# Downloaded 260000 features...
# Downloaded 262000 features...
# Downloaded 264000 features...
# Downloaded 266000 features...
# Downloaded 268000 features...
# Downloaded 270000 features...
# Downloaded 272000 features...
# Downloaded 274000 features...
# Downloaded 276000 features...
# Downloaded 278000 features...
# Downloaded 280000 features...
# Downloaded 282000 features...
# Downloaded 284000 features...
# Downloaded 286000 features...
# Downloaded 288000 features...
# Downloaded 290000 features...
# Downloaded 292000 features...
# Downloaded 294000 features...
# Downloaded 296000 features...
# Downloaded 298000 features...
# Downloaded 300000 features...
# Downloaded 302000 features...
# Downloaded 304000 features...
# Downloaded 306000 features...
# Downloaded 308000 features...
# Downloaded 310000 features...
# Downloaded 312000 features...
# Downloaded 314000 features...
# Downloaded 316000 features...
# Downloaded 318000 features...
# Downloaded 320000 features...
# Downloaded 322000 features...
# Downloaded 324000 features...
# Downloaded 326000 features...
# Downloaded 328000 features...
# Downloaded 330000 features...
# Downloaded 332000 features...
# Downloaded 334000 features...
# Downloaded 336000 features...
# Downloaded 338000 features...
# Downloaded 340000 features...
# Downloaded 342000 features...
# Downloaded 344000 features...
# Downloaded 346000 features...
# Downloaded 348000 features...
# Downloaded 350000 features...
# Downloaded 352000 features...
# Downloaded 354000 features...
# Downloaded 356000 features...
# Downloaded 358000 features...
# Downloaded 360000 features...
# Downloaded 362000 features...
# Downloaded 364000 features...
# Downloaded 366000 features...
# Downloaded 368000 features...
# Downloaded 370000 features...
# Downloaded 372000 features...
# Downloaded 374000 features...
# Downloaded 376000 features...
# Downloaded 378000 features...
# Downloaded 380000 features...
# Downloaded 382000 features...
# Downloaded 384000 features...
# Downloaded 386000 features...
# Downloaded 388000 features...
# Downloaded 390000 features...
# Downloaded 392000 features...
# Downloaded 394000 features...
# Downloaded 396000 features...
# Downloaded 398000 features...
# Downloaded 400000 features...
# Downloaded 402000 features...
# Downloaded 404000 features...
# Downloaded 406000 features...
# Downloaded 408000 features...
# Downloaded 410000 features...
# Downloaded 412000 features...
# Downloaded 414000 features...
# Downloaded 416000 features...
# Downloaded 418000 features...
# Downloaded 420000 features...
# Downloaded 422000 features...
# Downloaded 424000 features...
# Downloaded 426000 features...
# Downloaded 428000 features...
# Downloaded 430000 features...
# Downloaded 432000 features...
# Downloaded 434000 features...
# Downloaded 436000 features...
# Downloaded 438000 features...
# Downloaded 440000 features...
# Downloaded 442000 features...
# Downloaded 444000 features...
# Downloaded 446000 features...
# Downloaded 448000 features...
# Downloaded 450000 features...
# Downloaded 452000 features...
# Downloaded 454000 features...
# Downloaded 456000 features...
# Downloaded 458000 features...
# Downloaded 460000 features...
# Downloaded 462000 features...
# Downloaded 464000 features...
# Downloaded 466000 features...
# Downloaded 468000 features...
# Downloaded 470000 features...
# Downloaded 472000 features...
# Downloaded 474000 features...
# Downloaded 476000 features...
# Downloaded 478000 features...
# Downloaded 480000 features...
# Downloaded 482000 features...
# Downloaded 484000 features...
# Downloaded 486000 features...
# Downloaded 488000 features...
# Downloaded 490000 features...
# Downloaded 492000 features...
# Downloaded 494000 features...
# Downloaded 496000 features...
# Downloaded 498000 features...
# Downloaded 500000 features...
# Downloaded 502000 features...
# Downloaded 504000 features...
# Downloaded 506000 features...
# Downloaded 508000 features...
# Downloaded 510000 features...
# Downloaded 512000 features...
# Downloaded 514000 features...
# Downloaded 516000 features...
# Downloaded 518000 features...
# Downloaded 520000 features...
# Downloaded 522000 features...
# Downloaded 524000 features...
# Downloaded 526000 features...
# Downloaded 528000 features...
# Downloaded 530000 features...
# Downloaded 532000 features...
# Downloaded 534000 features...
# Downloaded 536000 features...
# Downloaded 538000 features...
# Downloaded 540000 features...
# Downloaded 542000 features...
# Downloaded 544000 features...
# Downloaded 546000 features...
# Downloaded 548000 features...
# Downloaded 550000 features...
# Downloaded 552000 features...
# Downloaded 554000 features...
# Downloaded 556000 features...
# Downloaded 558000 features...
# Downloaded 560000 features...
# Downloaded 562000 features...
# Downloaded 564000 features...
# Downloaded 566000 features...
# Downloaded 568000 features...
# Downloaded 570000 features...
# Downloaded 572000 features...
# Downloaded 574000 features...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 25
#      22 params = base_params.copy()
#      23 params["resultOffset"] = offset
# ---> 25 response = requests.get(url, params=params)
#      26 data = response.json()
#      28 features = data.get("features", [])
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/envs/uds/lib/python3.12/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/envs/uds/lib/python3.12/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File /opt/anaconda3/envs/uds/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/anaconda3/envs/uds/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/anaconda3/envs/uds/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /opt/anaconda3/envs/uds/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/envs/uds/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### By OSM

# %%
import osmnx as ox

# to manipulate data
import pandas as pd

# for interactive plots
import plotly.express as px

# to manipulate and visualize spatial data
import geopandas as gpd

# to provide basemaps 
import contextily as ctx

# to give more power to your figures (plots)
import matplotlib.pyplot as plt

# %%
import osmnx as ox

# 建物用途データを取得（例：Beverly Hills）
gdf = ox.features_from_place(
    "Beverly Hills, Los Angeles County, California",
    tags={"building": True}
)

# %%
import matplotlib.pyplot as plt

# landuseの種類を色分けしてプロット
gdf.plot(column="building", cmap="Set3", legend=True, figsize=(10,10))
plt.title("Building types in Beverly Hills")
plt.show()
